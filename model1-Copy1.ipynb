# %% [markdown]
# # Inaugural model

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import mysql.connector
import pandas.io.sql as psql
from mysql.connector import errorcode

# %% [markdown]
# ## Connect to database of field service tickets

# %%
try:
 conn = mysql.connector.connect(user='tgreen', password='3.1415Resolve',
                              host='resolv2-prod-db.cjpsepzc9py6.us-east-1.rds.amazonaws.com',
                              database='tara')
except mysql.connector.Error as err:
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  else:
    print(err)

# %%
cur = conn.cursor()

# %%
ticket1 = '''SELECT Ticket_Id
, Asset_Id
, Ticket_Status
, Need_To_Respond
, Ticket_Creation_Reason
, Ticket_Origin
, Portfolio
, Service_Type
, Covered
, Service_Partner
, Ticket_Tags
, Resolution_Code
, Date_Ticket_Initially_Assigned
, Date_Ticket_Closed
, Post_Service_Production_Status_New
, Post_Service_Communication_Status_New
FROM Zendesk_Tickets
'''

# %%
dftix = pd.read_sql(ticket1, con=conn)

# %%
dftix.head()
# Out:
#    Ticket_Id Asset_Id Ticket_Status  Need_To_Respond  \
# 0      30858                 Closed                0
# 1       5221                 Closed                0
# 2       5222                 Closed                0
# 3       5047                 Closed                0
# 4       5027                 Closed                0
#
#          Ticket_Creation_Reason             Ticket_Origin Portfolio  \
# 0  inquiry about service ticket  origin_omnidian_customer  Omnidian
# 1              duplicate ticket                            Omnidian
# 2                    unassigned                            Omnidian
# 3                    unassigned                            Omnidian
# 4              duplicate ticket                            Omnidian
#
#      Service_Type  Covered        Service_Partner  \
# 0  Remote Support  covered  Omnidian Support Team
# 1  Remote Support  covered  Omnidian Support Team
# 2  Remote Support  covered  Omnidian Support Team
# 3  Remote Support  covered  Omnidian Support Team
# 4  Remote Support  covered  Omnidian Support Team
#
#                                          Ticket_Tags Resolution_Code  \
# 0  closed_by_merge,origin_omnidian_customer,ticke...      unassigned
# 1  billable_to_not_billable,closed_by_omnidian,om...      unassigned
# 2  closed_by_omnidian,ticket_updated_by_service_p...      unassigned
# 3  closed_by_omnidian,omnidian_made_comment,ticke...      unassigned
# 4  closed_by_omnidian,omnidian_made_comment,ticke...      unassigned
#
#   Date_Ticket_Initially_Assigned Date_Ticket_Closed  \
# 0            2019-02-27 00:31:42         2019-02-27
# 1                            NaT         2017-11-08
# 2            2017-11-08 16:33:42         2017-11-10
# 3                            NaT         2017-10-31
# 4                            NaT         2017-10-31
#
#   Post_Service_Production_Status_New Post_Service_Communication_Status_New
# 0
# 1
# 2
# 3
# 4

# %%
dftix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36717 entries, 0 to 36716
# Data columns (total 16 columns):
# Ticket_Id                                36717 non-null int64
# Asset_Id                                 36717 non-null object
# Ticket_Status                            36717 non-null object
# Need_To_Respond                          36717 non-null int64
# Ticket_Creation_Reason                   36717 non-null object
# Ticket_Origin                            36717 non-null object
# Portfolio                                36717 non-null object
# Service_Type                             36717 non-null object
# Covered                                  36717 non-null object
# Service_Partner                          36717 non-null object
# Ticket_Tags                              36717 non-null object
# Resolution_Code                          36717 non-null object
# Date_Ticket_Initially_Assigned           35637 non-null datetime64[ns]
# Date_Ticket_Closed                       36717 non-null object
# Post_Service_Production_Status_New       36717 non-null object
# Post_Service_Communication_Status_New    36717 non-null object
# dtypes: datetime64[ns](1), int64(2), object(13)
# memory usage: 4.5+ MB

# %%
dftix.Resolution_Code.unique()
# Out:
# array(['unassigned', 'replace panel', 'inspect system',
#        'repair wiring and connectors', 'provide general information',
#        'provide production report', 'Omnidian cancelled ticket',
#        'service partner declined ticket',
#        'incorrect homeowner information', 'homeowner declined service',
#        'replace monitoring hardware', 'reset monitoring hardware',
#        'activate monitoring hardware', 'reset inverter', 'inspect roof',
#        'remote troubleshooting', 'repair inverter',
#        'repair monitoring network', 'provide quote for service work',
#        'replace GFDI fuse (in inverter)', 'install system',
#        'replace inverter',
#        'replace breaker or fuse (in main service panel)',
#        'homeowner non-responsive', 'repair roof', 'provide ticket update',
#        'document shade report', 'transferred call to partner',
#        'install junction box', 'clean system', 'replace junction box',
#        'remove system', 'document monitoring hardware',
#        'install monitoring hardware', '',
#        'repair mounting and racking hardware', 'activate system',
#        'replace AC disconnect', 'non-service business inquiry',
#        'replace DC power electronics', 'install wildlife guard',
#        'deactive system',
#        'advised homeowner that portal is no longer availab',
#        'system inaccessible', 'repair water tank',
#        'repair thermal system component', 'repair conduit',
#        'replace thermal system component', 'install controller',
#        'advised homeowner that PG is not owed', 'install panel',
#        'remote system inspection', 'repair home', 'replace DC disconnect',
#        'repair wildlife guard', 'install snow guard',
#        'dropship PLA installation', 'replace battery'], dtype=object)

# %%
dftix.Resolution_Code.value_counts()
# Out:
# unassigned                                            17012
# provide general information                            3761
# Omnidian cancelled ticket                              2549
# inspect system                                         2070
# provide production report                              1645
# homeowner non-responsive                                798
# deactive system                                         741
# reset monitoring hardware                               675
# repair monitoring network                               558
# provide quote for service work                          537
# provide ticket update                                   531
# replace inverter                                        524
# homeowner declined service                              523
# replace monitoring hardware                             523
# advised homeowner that portal is no longer availab      463
# incorrect homeowner information                         455
# reset inverter                                          380
# transferred call to partner                             370
# repair wiring and connectors                            251
# service partner declined ticket                         229
# inspect roof                                            229
#                                                         203
# install monitoring hardware                             171
# repair inverter                                         166
# activate monitoring hardware                            154
# activate system                                         131
# system inaccessible                                     114
# replace panel                                           112
# install system                                          109
# clean system                                            108
# remote troubleshooting                                  108
# non-service business inquiry                             73
# repair roof                                              64
# remove system                                            57
# remote system inspection                                 49
# replace breaker or fuse (in main service panel)          40
# install wildlife guard                                   31
# advised homeowner that PG is not owed                    30
# replace GFDI fuse (in inverter)                          23
# install panel                                            17
# document monitoring hardware                             16
# dropship PLA installation                                15
# repair mounting and racking hardware                     14
# replace DC power electronics                             13
# document shade report                                    13
# repair conduit                                           10
# repair home                                              10
# repair thermal system component                           8
# replace junction box                                      6
# replace AC disconnect                                     5
# install snow guard                                        5
# install junction box                                      4
# replace thermal system component                          4
# repair wildlife guard                                     3
# replace DC disconnect                                     2
# repair water tank                                         2
# replace battery                                           2
# install controller                                        1
# Name: Resolution_Code, dtype: int64
